# %% [markdown]
# ## Data

# %%
movies = open('./movies.txt').readlines()
movies = list(map(str.strip, movies))

# %% [markdown]
# ## Setting up

# %%
# !pip install wordcloud
# Out:
# Requirement already satisfied: wordcloud in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (1.8.2.2)
# Requirement already satisfied: pillow in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from wordcloud) (9.3.0)
# Requirement already satisfied: matplotlib in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from wordcloud) (3.6.2)
# Requirement already satisfied: numpy>=1.6.1 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from wordcloud) (1.23.4)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: packaging>=20.0 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib->wordcloud) (21.3)
# Requirement already satisfied: contourpy>=1.0.1 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.0.6)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: six>=1.5 in /home/behzad/anaconda3/envs/py10/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
text = ' '.join(movies)

# %%
wordcloud = WordCloud(background_color='white').generate(text)
plt.imshow(wordcloud,)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)
